# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# 1  Tarjeta de crédito                   4   6.25184 -75.56359
# 2  Tarjeta de crédito                   1  10.39972 -75.51444
# 3               Nequi                   1   3.43722 -76.52250
# 4               Nequi                   1   6.25184 -75.56359

# %% [markdown]
# # 1. Análisis de facturación

# %%
ingreso_total_tienda1 = sum(tienda['Precio'])
ingreso_total_tienda2 = sum(tienda2['Precio'])
ingreso_total_tienda3 = sum(tienda3['Precio'])
ingreso_total_tienda4 = sum(tienda4['Precio'])
print(f"Ingreso total de las tiendas: \n Tienda 1: {ingreso_total_tienda1}\n Tienda 2: {ingreso_total_tienda2}\n Tienda 3: {ingreso_total_tienda3}\n Tienda 4: {ingreso_total_tienda4}")
# Out:
# Ingreso total de las tiendas:
#  Tienda 1: 1150880400.0
#  Tienda 2: 1116343500.0
#  Tienda 3: 1098019600.0
#  Tienda 4: 1038375700.0

# %%
import matplotlib.pyplot as plt

tiendas = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']

ingresos = [ingreso_total_tienda1, ingreso_total_tienda2, ingreso_total_tienda3, ingreso_total_tienda4]

plt.figure(figsize=(8, 4))
plt.barh(tiendas, ingresos, color='skyblue')
plt.xlabel('Ingresos totales')
plt.title('Ingresos totales por tienda - Gráfico de barras horizontales')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6, 6))
plt.pie(ingresos, labels=tiendas, autopct='%1.1f%%', startangle=90, colors=plt.cm.Set3.colors)
plt.title('Distribución del ingreso total por tienda')
plt.axis('equal')
plt.show()

# %% [markdown]
# # 2. Ventas por categoría

# %%
ventas_por_categoria_tienda1 = tienda.groupby('Categoría del Producto').size().reset_index(name= 'Cantidad vendida')
ventas_ordenadas1 = ventas_por_categoria_tienda1.sort_values(by='Cantidad vendida', ascending=False)
ventas_ordenadas1
# Out:
#     Categoría del Producto  Cantidad vendida
# 7                  Muebles               465
# 3             Electrónicos               448
# 5                 Juguetes               324
# 2        Electrodomésticos               312
# 1     Deportes y diversión               284
# 4   Instrumentos musicales               182
# 6                   Libros               173
# 0  Artículos para el hogar               171

# %%
plt.figure(figsize=(10, 6))
plt.barh(ventas_ordenadas1['Categoría del Producto'], ventas_ordenadas1['Cantidad vendida'], color='skyblue')
plt.xlabel('Cantidad vendida')
plt.ylabel('Categoría del Producto')
plt.title('Ventas por Categoría de Producto - Tienda 1')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %%
categorias = ventas_ordenadas1['Categoría del Producto']
cantidades = ventas_ordenadas1['Cantidad vendida']

plt.figure(figsize=(8, 8))
plt.pie(cantidades, labels=categorias, autopct='%1.1f%%', startangle=140)
plt.title('Distribución de Ventas por Categoría - Tienda 4')
plt.axis('equal')
plt.show()

# %%
ventas_por_categoria_tienda2 = tienda2.groupby('Categoría del Producto').size().reset_index(name= 'Cantidad vendida')
ventas_ordenadas2 = ventas_por_categoria_tienda2.sort_values(by='Cantidad vendida', ascending=False)
ventas_ordenadas2
# Out:
#     Categoría del Producto  Cantidad vendida
# 7                  Muebles               442
# 3             Electrónicos               422
# 5                 Juguetes               313
# 2        Electrodomésticos               305
# 1     Deportes y diversión               275
# 4   Instrumentos musicales               224
# 6                   Libros               197
# 0  Artículos para el hogar               181

# %%
plt.figure(figsize=(10, 6))
plt.barh(ventas_ordenadas2['Categoría del Producto'], ventas_ordenadas2['Cantidad vendida'], color='skyblue')
plt.xlabel('Cantidad vendida')
plt.ylabel('Categoría del Producto')
plt.title('Ventas por Categoría de Producto - Tienda 2')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %%
categorias = ventas_ordenadas2['Categoría del Producto']
cantidades = ventas_ordenadas2['Cantidad vendida']

plt.figure(figsize=(8, 8))
plt.pie(cantidades, labels=categorias, autopct='%1.1f%%', startangle=140)
plt.title('Distribución de Ventas por Categoría - Tienda 4')
plt.axis('equal')
plt.show()

# %%
ventas_por_categoria_tienda3 = tienda3.groupby('Categoría del Producto').size().reset_index(name= 'Cantidad vendida')
ventas_ordenadas3 = ventas_por_categoria_tienda3.sort_values(by='Cantidad vendida', ascending=False)
ventas_ordenadas3
# Out:
#     Categoría del Producto  Cantidad vendida
# 7                  Muebles               499
# 3             Electrónicos               451
# 5                 Juguetes               315
# 2        Electrodomésticos               278
# 1     Deportes y diversión               277
# 6                   Libros               185
# 0  Artículos para el hogar               177
# 4   Instrumentos musicales               177

# %%
plt.figure(figsize=(10, 6))
plt.barh(ventas_ordenadas3['Categoría del Producto'], ventas_ordenadas3['Cantidad vendida'], color='skyblue')
plt.xlabel('Cantidad vendida')
plt.ylabel('Categoría del Producto')
plt.title('Ventas por Categoría de Producto - Tienda 3')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %%
categorias = ventas_ordenadas3['Categoría del Producto']
cantidades = ventas_ordenadas3['Cantidad vendida']

plt.figure(figsize=(8, 8))
plt.pie(cantidades, labels=categorias, autopct='%1.1f%%', startangle=140)
plt.title('Distribución de Ventas por Categoría - Tienda 4')
plt.axis('equal')
plt.show()

# %%
ventas_por_categoria_tienda4 = tienda4.groupby('Categoría del Producto').size().reset_index(name= 'Cantidad vendida')
ventas_ordenadas4 = ventas_por_categoria_tienda4.sort_values(by='Cantidad vendida', ascending=False)
ventas_ordenadas4
# Out:
#     Categoría del Producto  Cantidad vendida
# 7                  Muebles               480
# 3             Electrónicos               451
# 5                 Juguetes               338
# 1     Deportes y diversión               277
# 2        Electrodomésticos               254
# 0  Artículos para el hogar               201
# 6                   Libros               187
# 4   Instrumentos musicales               170

# %%
plt.figure(figsize=(10, 6))
plt.barh(ventas_ordenadas4['Categoría del Producto'], ventas_ordenadas4['Cantidad vendida'], color='skyblue')
plt.xlabel('Cantidad vendida')
plt.ylabel('Categoría del Producto')
plt.title('Ventas por Categoría de Producto - Tienda 4')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %%
categorias = ventas_ordenadas4['Categoría del Producto']
cantidades = ventas_ordenadas4['Cantidad vendida']

plt.figure(figsize=(8, 8))
plt.pie(cantidades, labels=categorias, autopct='%1.1f%%', startangle=140)
plt.title('Distribución de Ventas por Categoría - Tienda 4')
plt.axis('equal')
plt.show()

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
promedio1 = tienda['Calificación'].mean()
print(f"Calificación promedio de la tienda 1: {promedio1:.2f}")
# Out:
# Calificación promedio de la tienda 1: 3.98

# %%
promedio2 = tienda2['Calificación'].mean()
print(f"Calificación promedio de la tienda 2: {promedio2:.2f}")
# Out:
# Calificación promedio de la tienda 2: 4.04

# %%
promedio3 = tienda3['Calificación'].mean()
print(f"Calificación promedio de la tienda 3: {promedio3:.2f}")
# Out:
# Calificación promedio de la tienda 3: 4.05

# %%
promedio4 = tienda4['Calificación'].mean()
print(f"Calificación promedio de la tienda 4: {promedio4:.2f}")
# Out:
# Calificación promedio de la tienda 4: 4.00

# %%
promedios = [promedio1, promedio2, promedio3, promedio4]

plt.figure(figsize=(8, 8))
plt.pie(promedios, labels=tiendas, autopct='%1.1f%%', startangle=90)
plt.title('Distribución de Calificación por Tienda')
plt.axis('equal')
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.plot(tiendas, promedios, marker='o', linestyle='-', color='blue')
plt.title('Promedio de Calificaciones por Tienda')
plt.xlabel('Tienda')
plt.ylabel('Promedio')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.fill_between(tiendas, promedios, color='skyblue', alpha=0.1)
plt.plot(tiendas, promedios, marker='o', color='blue')
plt.title('Promedio de Calificaciones por Tienda (Área)')
plt.xlabel('Tienda')
plt.ylabel('Promedio')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 4))
plt.bar(tiendas, ingresos, color='salmon')
plt.ylabel('Ingresos totales')
plt.title('Ingresos totales por tienda - Gráfico de columnas')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
cantidad_productos_vendidos = tienda.groupby('Producto').size().reset_index(name='Cantidad productos')
productos_ordenados1 = cantidad_productos_vendidos.sort_values(by='Cantidad productos', ascending=False)
productos_ordenados1
# Out:
#                        Producto  Cantidad productos
# 48                TV LED UHD 4K                  60
# 33                   Microondas                  60
# 1                       Armario                  60
# 40             Secadora de ropa                  58
# 9       Bloques de construcción                  56
# 32                Mesa de noche                  56
# 5           Balón de baloncesto                  55
# 50                 Vaso térmico                  54
# 23                    Impresora                  54
# 39                 Refrigerador                  54
# 8                     Bicicleta                  54
# 7                       Batería                  53
# 12    Carrito de control remoto                  52
# 15                   Cubertería                  52
# 35          Modelado predictivo                  51
# 3                   Auriculares                  50
# 0             Ajedrez de madera                  49
# 25                    Iphone 15                  49
# 29                 Lavavajillas                  48
# 22           Guitarra eléctrica                  47
# 28             Lavadora de ropa                  47
# 21            Guitarra acústica                  46
# 43             Silla de oficina                  46
# 47              Sofá reclinable                  46
# 20                       Estufa                  45
# 30               Mesa de centro                  44
# 10                     Cama box                  44
# 16              Cubo mágico 8x8                  44
# 27                Kit de bancas                  44
# 11                    Cama king                  44
# 45                     Smart TV                  44
# 26                Juego de mesa                  43
# 41                 Set de ollas                  43
# 46                   Smartwatch                  43
# 6             Balón de voleibol                  42
# 49                  Tablet ABXY                  42
# 18      Dashboards con Power BI                  42
# 44                       Sillón                  41
# 24    Iniciando en programación                  41
# 42                 Set de vasos                  41
# 2             Asistente virtual                  40
# 17           Cuerda para saltar                  40
# 36                  Muñeca bebé                  40
# 31              Mesa de comedor                  40
# 19               Dinosaurio Rex                  40
# 14  Ciencia de datos con Python                  39
# 34                      Mochila                  39
# 38                    Pandereta                  36
# 37              Olla de presión                  35
# 4     Auriculares con micrófono                  33
# 13                 Celular ABXY                  33

# %%
productos_mas_vendidos = productos_ordenados1['Producto']
cantidades = productos_ordenados1['Cantidad productos']

plt.figure(figsize=(8, 8))
plt.pie(cantidades, labels=productos_mas_vendidos, autopct='%1.1f%%', startangle=140)
plt.title('Distribución de Productos con mas ventas - Tienda 1')
plt.axis('equal')
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.plot(productos_mas_vendidos, cantidades, marker='o', linestyle='-', color='red')
plt.title('Productos con mas ventas - Tienda 1')
plt.xlabel('Producto')
plt.ylabel('Cantidad')
plt.grid(True)
plt.show()

# %%
cantidad_productos_vendidos = tienda2.groupby('Producto').size().reset_index(name='Cantidad productos')
productos_ordenados2 = cantidad_productos_vendidos.sort_values(by='Cantidad productos', ascending=False)
productos_ordenados2
# Out:
#                        Producto  Cantidad productos
# 24    Iniciando en programación                  65
# 33                   Microondas                  62
# 7                       Batería                  61
# 38                    Pandereta                  58
# 21            Guitarra acústica                  58
# 40             Secadora de ropa                  57
# 25                    Iphone 15                  55
# 9       Bloques de construcción                  54
# 1                       Armario                  54
# 41                 Set de ollas                  52
# 17           Cuerda para saltar                  50
# 43             Silla de oficina                  49
# 39                 Refrigerador                  49
# 28             Lavadora de ropa                  49
# 36                  Muñeca bebé                  48
# 22           Guitarra eléctrica                  47
# 50                 Vaso térmico                  47
# 10                     Cama box                  47
# 12    Carrito de control remoto                  47
# 42                 Set de vasos                  46
# 6             Balón de voleibol                  46
# 35          Modelado predictivo                  46
# 29                 Lavavajillas                  46
# 16              Cubo mágico 8x8                  45
# 11                    Cama king                  45
# 48                TV LED UHD 4K                  45
# 8                     Bicicleta                  45
# 30               Mesa de centro                  45
# 34                      Mochila                  45
# 27                Kit de bancas                  45
# 0             Ajedrez de madera                  45
# 4     Auriculares con micrófono                  44
# 46                   Smartwatch                  44
# 49                  Tablet ABXY                  44
# 37              Olla de presión                  44
# 32                Mesa de noche                  44
# 47              Sofá reclinable                  44
# 18      Dashboards con Power BI                  43
# 14  Ciencia de datos con Python                  43
# 5           Balón de baloncesto                  42
# 19               Dinosaurio Rex                  42
# 20                       Estufa                  42
# 13                 Celular ABXY                  41
# 45                     Smart TV                  40
# 15                   Cubertería                  39
# 2             Asistente virtual                  38
# 3                   Auriculares                  37
# 44                       Sillón                  35
# 23                    Impresora                  34
# 31              Mesa de comedor                  34
# 26                Juego de mesa                  32

# %%
productos_mas_vendidos = productos_ordenados2['Producto']
cantidades = productos_ordenados2['Cantidad productos']

plt.figure(figsize=(8, 8))
plt.pie(cantidades, labels=productos_mas_vendidos, autopct='%1.1f%%', startangle=140)
plt.title('Distribución de Productos con mas ventas - Tienda 2')
plt.axis('equal')
plt.show()

# %%
cantidad_productos_vendidos = tienda3.groupby('Producto').size().reset_index(name='Cantidad productos')
productos_ordenados3 = cantidad_productos_vendidos.sort_values(by='Cantidad productos', ascending=False)
productos_ordenados3
# Out:
#                        Producto  Cantidad productos
# 27                Kit de bancas                  57
# 11                    Cama king                  56
# 31              Mesa de comedor                  56
# 32                Mesa de noche                  55
# 41                 Set de ollas                  55
# 45                     Smart TV                  54
# 35          Modelado predictivo                  53
# 20                       Estufa                  53
# 17           Cuerda para saltar                  53
# 26                Juego de mesa                  52
# 12    Carrito de control remoto                  52
# 8                     Bicicleta                  52
# 29                 Lavavajillas                  52
# 38                    Pandereta                  51
# 5           Balón de baloncesto                  50
# 23                    Impresora                  50
# 39                 Refrigerador                  50
# 1                       Armario                  49
# 6             Balón de voleibol                  48
# 49                  Tablet ABXY                  48
# 37              Olla de presión                  47
# 44                       Sillón                  47
# 21            Guitarra acústica                  47
# 0             Ajedrez de madera                  47
# 43             Silla de oficina                  46
# 46                   Smartwatch                  46
# 25                    Iphone 15                  46
# 24    Iniciando en programación                  46
# 10                     Cama box                  46
# 19               Dinosaurio Rex                  46
# 14  Ciencia de datos con Python                  46
# 47              Sofá reclinable                  45
# 40             Secadora de ropa                  45
# 16              Cubo mágico 8x8                  44
# 13                 Celular ABXY                  44
# 3                   Auriculares                  43
# 28             Lavadora de ropa                  42
# 30               Mesa de centro                  42
# 48                TV LED UHD 4K                  42
# 7                       Batería                  41
# 18      Dashboards con Power BI                  40
# 36                  Muñeca bebé                  39
# 15                   Cubertería                  39
# 4     Auriculares con micrófono                  39
# 2             Asistente virtual                  39
# 22           Guitarra eléctrica                  38
# 50                 Vaso térmico                  38
# 34                      Mochila                  36
# 33                   Microondas                  36
# 42                 Set de vasos                  36
# 9       Bloques de construcción                  35

# %%
productos_mas_vendidos = productos_ordenados3['Producto']
cantidades = productos_ordenados3['Cantidad productos']

plt.figure(figsize=(8, 8))
plt.pie(cantidades, labels=productos_mas_vendidos, autopct='%1.1f%%', startangle=140)
plt.title('Distribución de Productos con mas ventas - Tienda 1')
plt.axis('equal')
plt.show()

# %%
cantidad_productos_vendidos = tienda4.groupby('Producto').size().reset_index(name='Cantidad productos')
productos_ordenados4 = cantidad_productos_vendidos.sort_values(by='Cantidad productos', ascending=False)
productos_ordenados4
# Out:
#                        Producto  Cantidad productos
# 10                     Cama box                  62
# 15                   Cubertería                  59
# 18      Dashboards con Power BI                  56
# 11                    Cama king                  56
# 31              Mesa de comedor                  55
# 32                Mesa de noche                  55
# 12    Carrito de control remoto                  55
# 9       Bloques de construcción                  54
# 45                     Smart TV                  54
# 38                    Pandereta                  52
# 35          Modelado predictivo                  50
# 23                    Impresora                  50
# 5           Balón de baloncesto                  50
# 41                 Set de ollas                  50
# 2             Asistente virtual                  50
# 36                  Muñeca bebé                  48
# 33                   Microondas                  48
# 26                Juego de mesa                  48
# 25                    Iphone 15                  48
# 50                 Vaso térmico                  48
# 6             Balón de voleibol                  48
# 7                       Batería                  48
# 20                       Estufa                  47
# 16              Cubo mágico 8x8                  47
# 19               Dinosaurio Rex                  47
# 47              Sofá reclinable                  47
# 42                 Set de vasos                  46
# 37              Olla de presión                  46
# 49                  Tablet ABXY                  45
# 44                       Sillón                  45
# 8                     Bicicleta                  45
# 30               Mesa de centro                  44
# 3                   Auriculares                  44
# 24    Iniciando en programación                  43
# 34                      Mochila                  43
# 29                 Lavavajillas                  43
# 17           Cuerda para saltar                  43
# 27                Kit de bancas                  42
# 4     Auriculares con micrófono                  42
# 40             Secadora de ropa                  40
# 43             Silla de oficina                  40
# 48                TV LED UHD 4K                  40
# 46                   Smartwatch                  39
# 13                 Celular ABXY                  39
# 0             Ajedrez de madera                  39
# 39                 Refrigerador                  38
# 14  Ciencia de datos con Python                  38
# 28             Lavadora de ropa                  38
# 21            Guitarra acústica                  37
# 1                       Armario                  34
# 22           Guitarra eléctrica                  33

# %%
productos_mas_vendidos = productos_ordenados4['Producto']
cantidades = productos_ordenados4['Cantidad productos']

plt.figure(figsize=(8, 8))
plt.pie(cantidades, labels=productos_mas_vendidos, autopct='%1.1f%%', startangle=140)
plt.title('Distribución de Productos con mas ventas - Tienda 1')
plt.axis('equal')
plt.show()

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
costo_promedio_envio_tienda1 = tienda['Costo de envío'].mean()
print(f"Costo de envío promedio de la tienda 1: {costo_promedio_envio_tienda1:.2f}")
# Out:
# Costo de envío promedio de la tienda 1: 26018.61

# %%
costo_promedio_envio_tienda2 = tienda2['Costo de envío'].mean()
print(f"Costo de envío promedio de la tienda 2: {costo_promedio_envio_tienda2:.2f}")
# Out:
# Costo de envío promedio de la tienda 2: 25216.24

# %%
costo_promedio_envio_tienda3 = tienda3['Costo de envío'].mean()
print(f"Costo de envío promedio de la tienda 3: {costo_promedio_envio_tienda3:.2f}")
# Out:
# Costo de envío promedio de la tienda 3: 24805.68

# %%
costo_promedio_envio_tienda4 = tienda4['Costo de envío'].mean()
print(f"Costo de envío promedio de la tienda 4: {costo_promedio_envio_tienda4:.2f}")
# Out:
# Costo de envío promedio de la tienda 4: 23459.46

# %%
costos = [costo_promedio_envio_tienda1, costo_promedio_envio_tienda2, costo_promedio_envio_tienda3, costo_promedio_envio_tienda4]

plt.figure(figsize=(8, 8))
plt.pie(costos, labels=tiendas, autopct='%1.1f%%', startangle=90)
plt.title('Costo de envio por Tienda')
plt.axis('equal')
plt.show()

# %%
plt.figure(figsize=(8, 4))
plt.bar(tiendas, costos, color='skyblue')
plt.ylabel('Costos totales de envio')
plt.title('Costos totales de envio por tienda')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Informe final

# %% [markdown]
# Tras analizar los factores clave, se recomienda que el Sr. Juan venda la Tienda 4 y mantenga las demás tiendas. A continuación, se justifica esta decisión considerando las fortalezas y debilidades de cada tienda:
#
# Tienda 1:
# Fortalezas: Mayores ingresos totales ($1,150,880,400), costos de envío promedio más bajos, y calificaciones sólidas.
# Debilidades: Ninguna significativa identificada.
#
# Razón para mantener: Su desempeño financiero líder y costos de envío competitivos la convierten en una tienda clave para la rentabilidad.
#
# Tienda 2:
# Fortalezas: Ingresos altos ($1,116,343,500), cercanos a la Tienda 1.
# Debilidades: Calificaciones promedio muy bajas, lo que podría indicar problemas de calidad o servicio.
#
# Razón para mantener: A pesar de las bajas calificaciones, sus ingresos son sólidos. Se recomienda mejorar la calidad del servicio para aumentar la satisfacción del cliente.
#
# Tienda 3:
# Fortalezas: Calificaciones decentes y buena representación en categorías de alto valor como electrodomésticos.
# Debilidades: Costos de envío promedio más altos y menores ingresos ($1,098,019,600).
#
# Razón para mantener: Aunque los costos de envío son altos, su enfoque en electrodomésticos puede ser estratégico para diversificar el portafolio.
#
# Tienda 4:
# Fortalezas: Mejores calificaciones promedio, lo que indica alta satisfacción del cliente.
# Debilidades: Menores ingresos totales ($1,038,375,700) y costos de envío relativamente altos.
#
# Razón para vender: A pesar de las altas calificaciones, sus ingresos son los más bajos, lo que sugiere un menor volumen de ventas o precios menos competitivos. Esto la hace menos atractiva frente a las otras tiendas.
#
# Recomendación Final: La Tienda 4 es la candidata para la venta debido a sus menores ingresos y costos de envío relativamente altos, a pesar de sus excelentes calificaciones. Mantener las Tiendas 1, 2 y 3 permitirá al Sr. Juan maximizar los ingresos y diversificar las categorías de productos, mientras se abordan las debilidades específicas (como las calificaciones bajas de la Tienda 2) para mejorar el desempeño general.

# %%
# %pip install seaborn
import seaborn as sns

plt.figure(figsize=(10, 8))
sns.kdeplot(
    x=tienda['lon'], y=tienda['lat'], weights=tienda['Precio'],
    cmap="Reds", fill=True, bw_adjust=0.5
)
plt.title("Mapa de calor de ventas")
plt.xlabel("Longitud")
plt.ylabel("Latitud")
plt.grid(True)
plt.show()
# Out:
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: seaborn in c:\users\propietario\appdata\local\programs\python\python312\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\propietario\appdata\local\programs\python\python312\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\propietario\appdata\local\programs\python\python312\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\propietario\appdata\local\programs\python\python312\lib\site-packages (from seaborn) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\propietario\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\propietario\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\propietario\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\propietario\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\propietario\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\propietario\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\propietario\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\propietario\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\propietario\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\propietario\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\propietario\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
